# %%
#install and then import matplotlib
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Seaborn library has the filter parameter named as hue (useful for deeper analysis of the data)

# %%
#uploading dataset
datairis = pd.read_csv("/content/sample_data/IRIS.csv")

# %%
# Viewing uploaded dataset
datairis
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# Finding unique variables in 'Species' column
datairis.species.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
# histogram
plt.hist(datairis['sepal_length'],facecolor ="peru",edgecolor ="blue",bins =5)

# %%
sns.violinplot(x='sepal_length', y='sepal_width', data=datairis, inner=None,color='lightgray')

# %%
pd.crosstab(datairis.sepal_length,datairis.sepal_width).plot(kind="bar")

# %% [markdown]
# 1. What is the distribution of sepal lengths and widths among the Iris species?

# %%
# KDE plot for Sepal Length
plt.subplot(1, 2, 1)
sns.kdeplot(data=datairis, x="sepal_length", hue="species", fill=True, common_norm=False)
plt.title("Distribution of Sepal Length by Species")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Density")

# KDE plot for Sepal Width
plt.subplot(1, 2, 2)
sns.kdeplot(data=datairis, x="sepal_width", hue="species", fill=True, common_norm=False)
plt.title("Distribution of Sepal Width by Species")
plt.xlabel("Sepal Width (cm)")
plt.ylabel("Density")
# Out:
# Text(0, 0.5, 'Density')

# %%
f, ax = plt.subplots(figsize=(11,5))
sns.boxplot(x='sepal_length', y="species",  data=datairis);

# %%
sns.barplot(x="sepal_length", hue="species", data=datairis);

# %%
sns.barplot(x="sepal_width", hue="species", data=datairis);

# %% [markdown]
# Inference : Sepal length in Setosa species is shorter compared to other two species
# Where as Sepal width in more in Setosa species compared to other two species
#
# Sepal length is range between 4.30cm to 7.90cm
# Sepal width is in range between 2cm to 4.40cm

# %% [markdown]
# 2. How does the petal length vary across different Iris species?

# %%
sns.barplot(x="petal_length" , hue="species", data=datairis);

# %% [markdown]
# Inference : Petal in Viginica species, where as its shortest in Setosa species
#
# Avg length is 3.76cm
#
# Petal length is between 1cm to 6.90cm

# %% [markdown]
# 3. Is there a relationship between sepal length and petal length?

# %%
datairis

# %%
sns.scatterplot(x='sepal_length',y='petal_length', data=datairis, hue='species')

# %%
#add regression line
sns.regplot(x="sepal_length", y="petal_length", data=datairis)

# %% [markdown]
# Inference : the co relation between these 2 variables is postive as the Regression line is going up

# %% [markdown]
# 4. How does the petal width vary across different Iris species?

# %%
sns.barplot(x="petal_width", hue="species", data=datairis);

# %% [markdown]
# Inference : Petals in Virginica species are wider than other 2 species. And its shortest in Setosa species
#
# the min width is 0.100000
# Whereas max width is 2.500000

# %% [markdown]
# 5. Are there any patterns observable in the pairwise relationships between features (sepal length, sepal width, petal length, petal width)?
#
# > Add blockquote

# %%
datairis

# %%
# @title species vs sepal_length

from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(datairis['species'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(datairis, x='sepal_length', y='species', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)

# %%
datairis["datairis.sepal_area"] = datairis.sepal_length * datairis.sepal_width
datairis["datairis.petal_area"] = datairis.petal_length * datairis.petal_width

# %%
datairis[['sepal_length', 'sepal_width']]
# Out:
#      sepal_length  sepal_width
# 0             5.1          3.5
# 1             4.9          3.0
# 2             4.7          3.2
# 3             4.6          3.1
# 4             5.0          3.6
# ..            ...          ...
# 145           6.7          3.0
# 146           6.3          2.5
# 147           6.5          3.0
# 148           6.2          3.4
# 149           5.9          3.0
#
# [150 rows x 2 columns]

# %%
sns.jointplot(x= 'sepal_length', y= 'sepal_width', data=datairis)

# %%
sns.pairplot(datairis, hue="species", diag_kind="hist",
    plot_kws={"alpha": 0.7}, diag_kws={"alpha": 0.7}
    )

# %% [markdown]
# Inference :
# 1. Petal length and width : Setosa species shows clear seperationg whereas other two species correlation overlap
# 2. Sepal lenght and width :

# %% [markdown]
# 6. Can we distinguish between Iris species based on sepal and petal measurements?
#
# Yes
# 1. Petal lenght and width of Setosa species are smaller compared to other tho species
# 2. Virginica having larger petal dimensions
# 3. Sepal measurement in Virginica and Versicolor specials are overlapping hence dificult to distinguish
